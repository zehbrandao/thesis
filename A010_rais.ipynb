# %% [markdown]
# # Distribuição Territorial de Oportunidades
#
# **AUTORIA:** [REDE MOB](https://www.redemob.com.br/)
#
# **REFERÊNCIA CONCEITUAL:** [Acesso a Oportunidades](https://github.com/ipeaGIT/acesso_oport)
#
# Este notebook converte três cadastros administrativos nacionais — RAIS para empregos formais, CNES para infraestrutura de saúde e Censo Escolar para educação básica — em superfícies contínuas de densidade. O objetivo é retratar, em mapas de calor, onde se concentram postos de trabalho, leitos hospitalares e matrículas escolares, permitindo avaliar quão bem essas oportunidades se distribuem no espaço urbano e orientar políticas de mobilidade e ordenamento territorial. O procedimento parte dos registros originais, saneia inconsistências, na medida do possível, e geocodifica cada endereço e por fim, gera gráficos descritivos e mapas de densidade.

# %% [markdown]
# ## Panorama
#
# - **O que é uma oportunidade?** No escopo Ipea, qualquer local que ofereça
#   1. **Postos de trabalho formais** (RAIS);
#   2. **Empregos em saúde** (CNES);
#   3. **Empregos em educação básica** (Censo Escolar).
#
# - **Fontes e periodicidade**
#   - **RAIS** – microdados anuais do Ministério do Trabalho; a extração ocorre através da réplica BigQuery do *Base dos Dados* para o ano especificado pelo usuário.
#   - **CNES** – cadastro mensal de estabelecimentos de saúde, disponibilizado pelo Ministério da Saúde.
#   - **Censo Escolar** – levantamento anual do Inep contendo informações a respeito de instituições que compõem a educação básica.
#   - **Catálogo de Escolas** – reúne informações gerais, incluindo endereço, da oferta educacional das escolas brasileiras de educação básica.
#   - **Cadastro Nacional de Endereços para FIns Estatísticos** - base de dados de abrangência nacional que contempla endereços georreferenciados de domicílios e estabelecimentos de todo o país.
#
# - **Fluxo de processamento**
#   1. **Extração na Base dos Dados** das três bases para os municípios definidos pelo usuário.
#   2. **Limpeza e harmonização**: tratamentos gerais de inconsistências e anomalias e compatibilização de tabelas.
#   3. **Geocodificação**: geolocalização dos dados de acordo com latitude e longitude, quando disponíveis, ou localização aproximada com base no CEP.
#   5. **Geração resultados**: mapas de calor e gráficos descritivos gerais, além de exportação de resultados-chave .

# %% [markdown]
# ## PRODUTOS GERADOS
#
# 1. **Base integrada de oportunidades de trabalho**
#    Conjunto tabular no formato Parquet em que cada registro corresponde a um estabelecimento e traz, compatibilizados e integrados:
#    - vínculos formais provenientes da RAIS (setor privado);
#    - empregos “restituídos” em saúde e educação, obtidos respectivamente do CNES (profissionais de saúde) e do Censo Escolar (docentes + outros trabalhadores), para compensar a eliminação prévia dos vínculos da administração pública.
#
# 2. **Base de escolas de ensino básico**
#    Arquivo Parquet georreferenciado contendo a localização das unidades escolares, número de matrículas, quantidade de docentes e demais trabalhadores, discriminados por rede (pública × privada).
#
# 3. **Base de estabelecimentos de saúde**
#    Arquivo Parquet georreferenciado no qual cada linha representa um estabelecimento classificado por nível de complexidade; inclui oferta de leitos, número de consultórios e contingente de profissionais cadastrados.
#
# 4. **Mapas e estatísticas descritivas**
#    - Mapas de calor interativos para cada categoria de oportunidade (empregos, saúde, educação).
#    - Gráficos com descritivos gerais.

# %% [markdown]
# ## LIMITAÇÕES
#
# 1. **Geocodificação por CEP**
#     - O CEP identifica logradouros inteiros. Embora isso não seja um problema em áreas urbanas mais consolidadas, estudos mostram que pode haver erros superiores a 150 m em áreas periféricas e rurais, o que pode deslocar artificialmente a densidade de oportunidades nesses locais. Mas, mesmo assim, isso tende a não ser um problema quando se deseja uma análise em um nível mais global. O problema maior ocorre em locais mais ermos ou em municípios muito pequenos, muitas vezes identificados por apenas um único CEP nas bases que temos disponíveis.
#
# 2. **Inconsistências nos cadastros**
#     - Apesar da confiabilidade nos cadastros de dados, não se deve assumir que inexistem erros cadastrais que levam a quantidades erradas desta ou daquela varivável. Além disso, eventualmente ocorrem casos de equipamentos públicos importantes cadastrados em locais errados.
#     - Auditorias independentes apontam discrepâncias frequentes entre o número de leitos declarados no CNES e a realidade verificada *in loco*.
#     - Isso é esperado em bases cadastrais da magnitude das utilizadas aqui e não invalidam seu uso. Apenas mencionamos isso como alerta para que sejam avaliados criticamente os resultados.
#
# 3. **Cobertura apenas do emprego formal**
#     - A RAIS alcança vínculos com carteira assinada; ocupações informais — significativas no comércio ambulante e na construção civil, por exemplo — não entram no cálculo, resultando em subestimação de oportunidades nessas atividades. Esse é um problema até hoje de difícil resolução.
#
# 4. **Exclusão do setor público**
#     - O setor público frequentemente declara seus funcionários apenas na sede administrativa ou da respectiva secretaria, o que pode gerar distorções significativas se esses dados forem utilizados. A título de exemplo, todos os empregos de docentes do Estado de Minas Gerais estavam declarados na localização não das respectivas escolas, mas na secretaria de educação em Belo Horizonte. No entanto, para o caso de empregos na saúde e no ensino, derivamos a quantidade de postos de trabalho geolocalizadas de acordo com o CNES e o Censo Escolar.
#
# 5. **Versões preliminar × definitiva da RAIS**
#     - O Ministério do Trabalho publica uma versão *Preliminar* e, meses depois, a *Definitiva*; diferenças decorrem de declarações fora do prazo e retificações compulsórias.
#
# 6. **Mudança metodológica (2019–2023)**
#     - A incorporação gradual do eSocial alterou cobertura, prazos de coleta e estrutura de variáveis: grupos 1 e 2 migraram em 2019, grupo 3 em 2022 e grupo 4 em 2023. Comparar anos anteriores e posteriores a esse intervalo exige ajuste ou, no mínimo, interpretação cautelosa.

# %% [markdown]
# ## Instruções
#
# Este notebook requer:
#
# 1. **Lista de [códigos do IBGE](https://www.ibge.gov.br/explica/codigos-dos-municipios.php)** dos municípios de interesse.
# 2. **[Credenciais BigQuery]((https://basedosdados.org/docs/access_data_bq))** (`GCLOUD_ID`) para consultar RAIS, CNES e Censo Escolar.
# 3. **Ano e mês de referência** coerentes entre as três fontes.
# 4. **Diretório de saída** (`OUTPUT_DIR`) para armazenar outputs.

# %% [markdown]
# ## Parâmetros Definidos Pelo Usuário
#
# | Parâmetro     | Descrição                                    | Exemplo                     |
# |---------------|----------------------------------------------|-----------------------------|
# | `MUNIS`       | Lista de códigos IBGE                        | `[3303302, 3304904]`        |
# | `YEAR`        | Ano base                                     | `2023`                      |
# | `CNES_MONTH`  | Mês de corte do CNES (1–12)                  | `10`                        |
# | `OUTPUT_DIR`  | Pasta para resultados                        | `"outputs_oportunidades/"`  |
#
# ```python
# # ---- Exemplo 1 ------------------------------------------------------
# GCLOUD_ID   = 'seu-projeto-google-cloud'         # Nome do projeto no Google
# MUNIS       = [3303302, 3304904]                 # municípios-alvo
# YEAR        = 2023                               # ano comum às bases
# CNES_MONTH  = 10                                 # mês CNES
# OUTPUT_DIR  = "outputs_oportunidades"
# # ----------------------------------------------------------------------

# %% [markdown]
# ---
# ## Utilização
# 1. **Atualize** os parâmetros na célula abaixo.
# 2. **Execute** todo o notebook; os produtos serão salvos em `OUTPUT_DIR`.
# 3. **Analise** os mapas de calor e estatísticas conforme suas questões de política pública ou pesquisa.
# 4. **Role** o notebook para acompanhar o passo a passo metodológico em Python. Os primeiros resultados aparecem logo após a seção **Backend**. O código não precisa ser editado, mas permanece visível para transparência e customização por usuários avançados.

# %%
###############################################################################
# Definições de parâmetros ajustáveis pelo usuário                            #
###############################################################################
GCLOUD_ID    = None                                 # Nome do projeto no Google
MUNIS        = [3106200]  # municípios-alvo
YEARS        = list(range(2023, 2024))                   # anos comuns às bases
CNES_MONTHS  = 8                                   # meses CNES


###############################################################################
# Parâmetros para uso avançado                                                #
###############################################################################
# Manter igual a YEAR é a prática recomendada. A NÃO SER que tenha necessidade
# muito específica, não mexer.
RAIS_YEARS  = YEARS                 # RAIS (emprego)
CENSO_YEARS = YEARS                 # Censo Escolar
CNES_YEARS  = YEARS                 # CNES

# %% [markdown]
# # Backend

# %% [markdown]
# ## Set Up Inicial

# %%
from __future__ import annotations

# ── standard-library imports ─────────────────────────────────────────
import functools
import os
from pathlib import Path
from string import ascii_uppercase
from typing import Any, Iterable, Mapping, Sequence, Tuple
import unicodedata

# ── third-party imports ──────────────────────────────────────────────
import basedosdados as bd
from dotenv import load_dotenv
import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import plotly.express as px
import seaborn as sns

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.style.use('Solarize_Light2')

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %%
if not GCLOUD_ID:
    load_dotenv()
    GCLOUD_ID = os.getenv("GCLOUD_ID")

OUT_FOLDER = os.environ.get('OUT_FOLDER')
OUT_DIR = Path(OUT_FOLDER) / 'A/oportunidades'
OUT_DIR.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Constantes

# %%
# Cell 2 – shared constants

# ── CNAE prefixes whose employment counts may be capped ──────────────
_PROBLEM_PREFIXES: list[str] = [
    '35', # ELETRICIDADE, GÁS E OUTRAS UTILIDADES
    '36', # CAPTAÇÃO, TRATAMENTO E DISTRIBUIÇÃO DE ÁGUA
    '38', # COLETA, TRATAMENTO E DISPOSIÇÃO DE RESÍDUOS; RECUPERAÇÃO DE MATERIAIS
    '41', # CONSTRUÇÃO DE EDIFÍCIOS
    '42', # OBRAS DE INFRA-ESTRUTURA
    '43', # SERVIÇOS ESPECIALIZADOS PARA CONSTRUÇÃO
    '49', # TRANSPORTE TERRESTRE
    '51', # TRANSPORTE AÉREO
    '562', # Catering, bufê e outros serviços de comida preparada
    '64', # ATIVIDADES DE SERVIÇOS FINANCEIROS
    '78', # SELEÇÃO, AGENCIAMENTO E LOCAÇÃO DE MÃO-DE-OBRA
    '80', # ATIVIDADES DE VIGILÂNCIA, SEGURANÇA E INVESTIGAÇÃO
    '81', # SERVIÇOS PARA EDIFÍCIOS E ATIVIDADES PAISAGÍSTICAS
    '82', # SERVIÇOS DE ESCRITÓRIO, DE APOIO ADMINISTRATIVO E OUTROS SERVIÇOS PRESTADOS A EMPRESAS
    '84', # ADMINISTRAÇÃO PÚBLICA, DEFESA E SEGURIDADE SOCIAL
]
_RX_PROBLEM: str = rf"^({'|'.join(_PROBLEM_PREFIXES)})"

# ── CNES establishment types selected by upstream notebooks ──────────
_UNIT_CODES: list[str] = [
    "1",   # Hospital Geral
    "2",   # Hospital Especializado
    "3",   # Hospital-Dia
    "4",   # Unidade Mista
    "5",   # Unidade Básica de Saúde
    "6",   # Posto de Saúde
    "7",   # Centro de Saúde/Unidade Básica
    "8",   # Policlínica
    "9",   # Unidade Móvel Terrestre
    "10",  # Pronto Socorro Geral
    "11",  # Pronto Socorro Especializado
    "12",  # Unidade de Apoio à Diagnose e Terapia
    "13",  # Unidade de Atenção Especializada Ambulatorial
    "14",  # Centro de Parto Normal - Isolado
    "15",  # Centro de Atenção Hemoterapia e Hematologia
    "16",  # Centro de Atenção à Saúde Auditiva
    "17",  # Centro de Especialidades Odontológicas
    "18",  # Centro de Reabilitação
    "19",  # Hospital de Ensino
    "20",  # Unidade de Pronto Atendimento (UPA 24h)
    "21",  # Centro de Saúde Escola
]

# ── Mapping of infrastructure groups to CNES column names ────────────
INFRASTRUCTURE_GROUPS: dict[str, list[str]] = {
    "total_leitos_internacao": [
        "quantidade_leito_clinico",
        "quantidade_leito_cirurgico",
        "quantidade_leito_complementar",
    ],
    "total_leitos_observacao": [
        "quantidade_leito_repouso_pediatrico_urgencia",
        "quantidade_leito_repouso_feminino_urgencia",
        "quantidade_leito_repouso_masculino_urgencia",
        "quantidade_leito_repouso_indiferenciado_urgencia",
        "quantidade_leito_repouso_feminino_ambulatorial",
        "quantidade_leito_repouso_masculino_ambulatorial",
        "quantidade_leito_repouso_pediatrico_ambulatorial",
        "quantidade_leito_repouso_indiferenciado_ambulatorial",
        "quantidade_leito_recuperacao_centro_cirurgico",
    ],
    "total_leitos_materno_infantil": [
        "quantidade_leito_pre_parto_centro_obstetrico",
        "quantidade_leito_recem_nascido_normal_neonatal",
        "quantidade_leito_recem_nascido_patologico_neonatal",
        "quantidade_leito_conjunto_neonatal",
    ],
    "total_consultorios": [
        "quantidade_consultorio_medico_urgencia",
        "quantidade_consultorio_pediatrico_urgencia",
        "quantidade_consultorio_feminino_urgencia",
        "quantidade_consultorio_masculino_urgencia",
        "quantidade_consultorio_indiferenciado_urgencia",
        "quantidade_consultorio_odontologia_urgencia",
        "quantidade_consultorio_clinica_basica_ambulatorial",
        "quantidade_consultorio_clinica_especializada_ambulatorial",
        "quantidade_consultorio_clinica_indiferenciada_ambulatorial",
        "quantidade_consultorio_nao_medico_ambulatorial",
        "quantidade_consultorio_odontologia_ambulatorial",
    ],
    "total_salas_procedimentos": [
        "quantidade_sala_curativo_urgencia",
        "quantidade_sala_gesso_urgencia",
        "quantidade_sala_pequena_cirurgia_urgencia",
        "quantidade_sala_higienizacao_urgencia",
        "quantidade_sala_curativo_ambulatorial",
        "quantidade_sala_gesso_ambulatorial",
        "quantidade_sala_pequena_cirurgia_ambulatorial",
        "quantidade_sala_enfermagem_ambulatorial",
        "quantidade_sala_imunizacao_ambulatorial",
        "quantidade_sala_nebulizacao_ambulatorial",
    ],
    "total_salas_cirurgicas_obstetricas": [
        "quantidade_sala_cirurgia_ambulatorial",
        "quantidade_sala_cirurgia_ambulatorial_centro_cirurgico",
        "quantidade_sala_cirurgia_centro_cirurgico",
        "quantidade_sala_recuperacao_centro_cirurgico",
        "quantidade_sala_pre_parto_centro_obstetrico",
        "quantidade_sala_parto_normal_centro_obstetrico",
        "quantidade_sala_curetagem_centro_obstetrico",
        "quantidade_sala_cirurgia_centro_obstetrico",
    ],
}


# Mapeamento oficial de Seções CNAE → intervalos de divisão
_CNAE_SECTIONS: list[Tuple[str,int,int]] = [
    ("A",   1,   3),  # Agricultura, Pecuária, Produção Florestal, Pesca e Aqüicultura
    ("B",   5,   9),  # Indústrias Extrativas
    ("C",  10,  33),  # Indústrias de Transformação
    ("D",  35,  35),  # Eletricidade e Gás
    ("E",  36,  39),  # Água, Esgoto, Ativ. de Gestão de Resíduos e Descontaminação
    ("F",  41,  43),  # Construção
    ("G",  45,  47),  # Comércio; Reparação de Veículos Automotores e Motocicletas
    ("H",  49,  53),  # Transporte, Armazenagem e Correio
    ("I",  55,  56),  # Alojamento e Alimentação
    ("J",  58,  63),  # Informação e Comunicação
    ("K",  64,  66),  # Atividades Financeiras, de Seguros e Serviços Relacionados
    ("L",  68,  68),  # Atividades Imobiliárias
    ("M",  69,  75),  # Atividades Profissionais, Científicas e Técnicas
    ("N",  77,  82),  # Atividades Administrativas e Serviços Complementares
    ("O",  84,  84),  # Administração Pública, Defesa e Seguridade Social
    ("P",  85,  85),  # Educação
    ("Q",  86,  88),  # Saúde Humana e Serviços Sociais
    ("R",  90,  93),  # Artes, Cultura, Esporte e Recreação
    ("S",  94,  96),  # Outras Atividades de Serviços
    ("T",  97,  97),  # Serviços Domésticos
    ("U",  99,  99),  # Organismos Internacionais e Outras Instituições Extraterritoriais
]

# %% [markdown]
# ## Extração dos Dados

# %%
def sql_list(values: Sequence[Any],
             *,
             quote: bool = False,
             pad: int | None = None) -> str:
    """
    Convert *values* to a comma-separated literal list suitable for
    «… IN (…)» clauses.

    Parameters
    ----------
    values : iterable of scalars
    quote  : wrap each element in single quotes when True
    pad    : zero-left-pad integers / numeric strings to fixed width
    """
    vals = list(
        np.atleast_1d(values)
        )
    if not vals:
        raise ValueError("Sequence must not be empty.")

    def _fmt(v: Any) -> str:
        s = str(int(v) if isinstance(v, (int, float)) else v)
        if pad is not None:
            s = s.zfill(pad)
        return f"'{s}'" if quote else s

    return ", ".join(_fmt(v) for v in vals)


muni_list = functools.partial(sql_list, quote=True, pad=7)

# %%
def _group_expressions() -> str:
    """
    Compose COALESCE-protected SUMs for every entry in
    the global ``INFRASTRUCTURE_GROUPS`` dictionary.
    """
    out: list[str] = []
    for alias, cols in INFRASTRUCTURE_GROUPS.items():
        summands = " + ".join(f"COALESCE({c},0)" for c in cols)
        out.append(f"{summands} AS {alias}")
    return ",\n                ".join(out)

# %%
def fetch_schools(
    muni_ids: Sequence[int | str],
    *,
    years: Sequence[int] | int = 2023,
    billing_project_id: str | None = None,
) -> pd.DataFrame:
    """
    Fetch directory + Censo-Escolar data for *muni_ids*, already aggregated
    per the original notebook logic.
    """
    muni_ids_sql = muni_list(muni_ids)
    years_sql  = sql_list(years)
    
    query = f"""
        WITH dir AS (
          SELECT
            id_escola,
            id_municipio,
            dependencia_administrativa,
            etapas_modalidades_oferecidas,
            endereco,
            latitude,
            longitude
          FROM `basedosdados.br_bd_diretorios_brasil.escola`
          WHERE id_municipio IN ({muni_ids_sql})
            AND latitude  IS NOT NULL
            AND longitude IS NOT NULL
        ),

        cen AS (
          SELECT
            t.id_escola,
            t.ano,
            CASE
              WHEN CAST(t.rede AS STRING) IN ('1','2','3') THEN 'Publica'
              ELSE 'Privada'
            END AS rede,
            t.quantidade_matricula_infantil,
            t.quantidade_matricula_fundamental,
            t.quantidade_matricula_medio,
            t.quantidade_docente_educacao_basica,
            COALESCE((
              SELECT
                SUM(
                  CASE
                    WHEN SAFE_CAST(num AS INT64) = 88888 THEN 0
                    ELSE SAFE_CAST(num AS INT64)
                  END
                )
              FROM UNNEST(
                REGEXP_EXTRACT_ALL(
                  TO_JSON_STRING(t),
                  r'"quantidade_profissional_[^"]+":\s*([0-9]+)'
                )
              ) AS num
            ), 0) AS quantidade_profissional
          FROM `basedosdados.br_inep_censo_escolar.escola` AS t
          WHERE t.ano IN ({years_sql})
            AND t.id_municipio IN ({muni_ids_sql})
            AND t.regular = 1
            AND t.tipo_situacao_funcionamento = '1'
        )

        SELECT
          d.id_escola,
          d.id_municipio,
          d.dependencia_administrativa,
          d.etapas_modalidades_oferecidas,
          d.endereco,
          d.latitude,
          d.longitude,
          c.ano,
          c.rede,
          c.quantidade_matricula_infantil,
          c.quantidade_matricula_fundamental,
          c.quantidade_matricula_medio,
          c.quantidade_docente_educacao_basica,
          c.quantidade_profissional
        FROM dir AS d
        JOIN cen AS c USING (id_escola);
        """

    return bd.read_sql(query, billing_project_id=billing_project_id)

# %%
def fetch_healthcare(
    muni_ids: Sequence[int | str],
    *,
    years: Sequence[int] | int = 2023,
    months: Sequence[int] | int = 9,
    billing_project_id: str | None = None,
) -> pd.DataFrame:
    """
    CNES establishments enriched with infrastructure sums, workforce counts
    and highest complexity flag.
    """
    muni_sql  = muni_list(muni_ids)
    unit_sql  = sql_list(_UNIT_CODES, quote=True)
    infra_sql = _group_expressions()
    months_sql = sql_list(months)
    years_sql  = sql_list(years)

    query = f"""
      WITH estab AS (
        SELECT
          e.id_estabelecimento_cnes,
          e.id_municipio,
          e.cep,
          e.tipo_unidade,
          e.tipo_pessoa,
          e.indicador_vinculo_sus,
          e.indicador_atencao_hospitalar,
          e.ano,
          e.mes,

          CASE
            WHEN REGEXP_CONTAINS(
                  TO_JSON_STRING(e),
                  r'"indicador_gestao_alta_[^"]+":\s*1'
                ) THEN 'alta'
            WHEN REGEXP_CONTAINS(
                  TO_JSON_STRING(e),
                  r'"indicador_gestao_media_[^"]+":\s*1'
                ) THEN 'media'
            WHEN REGEXP_CONTAINS(
                  TO_JSON_STRING(e),
                  r'"indicador_gestao_basica_[^"]+":\s*1'
                ) THEN 'basica'
          END AS complexidade,

          {infra_sql}

        FROM `basedosdados.br_ms_cnes.estabelecimento` AS e
        WHERE e.id_municipio IN ({muni_sql})
          AND e.ano IN ({years_sql})          
          AND e.mes IN ({months_sql})         
          AND e.tipo_unidade IN ({unit_sql})
          AND e.tipo_pessoa = '3'            -- Pessoa Jurídica (CNPJ)
      ),

      workers AS (
        SELECT
          t.id_estabelecimento_cnes,
          t.ano,
          t.mes,
          COALESCE(
            SUM(
              CASE
                WHEN SAFE_CAST(num AS INT64) = 88888 THEN 0
                ELSE SAFE_CAST(num AS INT64)
              END
            ),
            0
          ) AS quantidade_trabalhadores_saude
        FROM `basedosdados.br_ms_cnes.profissional` AS t
        LEFT JOIN UNNEST(
          REGEXP_EXTRACT_ALL(
            TO_JSON_STRING(t),
            r'"quantidade_profissional_[^"]+":\s*([0-9]+)'
          )
        ) AS num ON TRUE
        WHERE t.id_municipio IN ({muni_sql})
          AND t.ano IN ({years_sql})          
          AND t.mes IN ({months_sql})         
        GROUP BY t.id_estabelecimento_cnes, t.ano, t.mes
      )

      SELECT
        e.*,
        COALESCE(w.quantidade_trabalhadores_saude, 0)
          AS quantidade_trabalhadores_saude
      FROM estab   AS e
      LEFT JOIN workers AS w USING (id_estabelecimento_cnes, ano, mes);
    """


    return bd.read_sql(query, billing_project_id=billing_project_id)

# %%
def fetch_rais(
    muni_ids: Sequence[int | str],
    years: Sequence[int] | int = 2022,
    *,
    billing_project_id: str | None = None,
) -> pd.DataFrame:
    """
    RAIS extractor with adaptive p95 cap for problematic CNAE prefixes.
    """
    mun_sql = muni_list(muni_ids)
    year_seq = years if isinstance(years, Iterable) else [years]
    yr_sql  = sql_list(year_seq)

    query = f"""
        WITH
        base AS (
            SELECT
                ano,
                id_municipio,
                tipo_estabelecimento,
                cnae_2,
                CAST(quantidade_vinculos_ativos AS INT64) AS jobs_raw,
                cep,
                REGEXP_SUBSTR(cnae_2, r'^\\d{{2,3}}') AS prefix
            FROM `basedosdados.br_me_rais.microdados_estabelecimentos`
            WHERE ano IN ({yr_sql})
                AND id_municipio IN ({mun_sql})
                AND (natureza_juridica IS NULL OR SUBSTR(natureza_juridica,1,1) != '1')
                AND (natureza_juridica IS NULL OR natureza_juridica != '2011')
            ),

        positive AS (
            SELECT * FROM base WHERE jobs_raw > 0
            ),
            
        p95_by_prefix_year AS (
            SELECT DISTINCT
                prefix,
                ano,
                PERCENTILE_CONT(jobs_raw, 0.95)
                OVER (PARTITION BY prefix, ano) AS p95
            FROM positive
            ),

        flagged AS (
            SELECT
                b.*,
                REGEXP_CONTAINS(b.cnae_2, r'{_RX_PROBLEM}') AS is_problem
            FROM base AS b
            ),

        capped AS (
            SELECT
                f.ano,
                f.id_municipio,
                f.tipo_estabelecimento,
                f.cnae_2,
                f.cep,
                CAST(
                    ROUND(
                        CASE
                        WHEN f.is_problem
                            AND p.p95 IS NOT NULL
                            AND f.jobs_raw > p.p95
                        THEN p.p95
                        ELSE COALESCE(f.jobs_raw, 0)
                        END
                        ) AS INT64
                    ) AS quantidade_vinculos_ativos
            FROM flagged AS f
            LEFT JOIN p95_by_prefix_year AS p
                ON p.prefix = f.prefix AND p.ano = f.ano
            )
        
        SELECT
        ano,
        id_municipio,
        tipo_estabelecimento,
        cnae_2,
        quantidade_vinculos_ativos,
        cep
        FROM capped
    """

    return bd.read_sql(query, billing_project_id=billing_project_id)

# %%
def load_ceps(
    muni_ids: Sequence[int | str],
    *,
    billing_project_id: str | None = None,
) -> pd.DataFrame:
    """
    Retorna um DataFrame com todos os CEPs (e o respectivo id_municipio)
    presentes para os municípios em *muni_ids* na tabela
    `basedosdados.br_bd_diretorios_brasil.cep`.

    Parameters
    ----------
    muni_ids : lista de códigos IBGE (int ou str) – sete dígitos
    billing_project_id : projeto GCP para faturamento no BigQuery

    Exemplo
    -------
    >>> ceps_df = load_ceps(MUNIS, billing_project_id=GCLOUD_ID)
    """
    muni_sql = muni_list(muni_ids)

    query = f"""
        SELECT *
        FROM `basedosdados.br_bd_diretorios_brasil.cep`
        WHERE id_municipio IN ({muni_sql})
    """

    return bd.read_sql(query, billing_project_id=billing_project_id)

# %% [markdown]
# ## Geolocalização

# %%
# ──────────────────────────── utilidades privadas ────────────────────────────
def _geometry_from_wkt(
    df: pd.DataFrame,
    *,
    wkt_col: str = "centroide",
    crs: str | int = "EPSG:4326",
) -> gpd.GeoDataFrame:
    """Converte coluna WKT em geometria (CRS WGS-84)."""
    geometry = gpd.GeoSeries.from_wkt(df[wkt_col], crs=crs)
    return gpd.GeoDataFrame(
        df, geometry=geometry, crs="EPSG:4326"
    ).drop(columns='centroide')


def _load_ceps_gdf(
    munis: Sequence[int | str], *, billing_project_id: str
) -> gpd.GeoDataFrame:
    """Baixa tabela de CEPs e devolve GeoDataFrame pronto para merge."""
    ceps_raw = load_ceps(munis, billing_project_id=billing_project_id)
    return _geometry_from_wkt(ceps_raw)


def _merge_by_cep(
    df: pd.DataFrame, cep_gdf: gpd.GeoDataFrame, *, cep_col: str = "cep"
) -> gpd.GeoDataFrame:
    """Une DataFrame a geometrias via CEP (mantém apenas linhas com match)."""
    df = df.copy()
    df[cep_col] = df[cep_col].astype(str).str.zfill(8)
    return (
        df.merge(cep_gdf[[cep_col, "geometry"]], on=cep_col, how="inner")
          .pipe(gpd.GeoDataFrame, geometry="geometry", crs="EPSG:4326")
    )


def _to_local_utm(gdf: gpd.GeoDataFrame) -> gpd.GeoDataFrame:
    """Reprojeta para o fuso UTM adequado ao bounding box do GeoDataFrame."""
    return gdf.to_crs(gdf.estimate_utm_crs(datum_name="SIRGAS 2000"))


# ──────────────────────────── interface principal ────────────────────────────
def load_geolocated_layers(
    munis: Sequence[int | str],
    *,
    years: int,
    cnes_months: int,
    billing_project_id: str,
    **kwargs,
) -> dict[str, gpd.GeoDataFrame]:
    """
    Devolve dicionário com três GeoDataFrames — ‘rais’, ‘cnes’, ‘schools’ — já
    georreferenciados (pontos) e reprojetados em UTM local.

    Parameters
    ----------
    munis : sequência de códigos IBGE (7 dígitos)
    years : anos de referência comuns aos três datasets
    cnes_months : meses de referência (1–12) para o CNES
    billing_project_id : projeto GCP para faturamento das consultas
    """
    # CEPs primeiro: base para geocodificação de RAIS e CNES
    ceps_gdf = _load_ceps_gdf(munis, billing_project_id=billing_project_id)

    # Escolas – já vêm com lat/lon
    schools_raw = fetch_schools(
        munis, years=years, billing_project_id=billing_project_id
    )
    schools_gdf = gpd.GeoDataFrame(
        schools_raw,
        geometry=gpd.points_from_xy(schools_raw.longitude, schools_raw.latitude),
        crs="EPSG:4326",
    ).pipe(_to_local_utm)

    # CNES – geocodificação via CEP
    cnes_raw = fetch_healthcare(
        munis,
        # TODO: adjust docs etc. for the variable cnes_year below
        years=years if kwargs.get("cnes_years") is None else kwargs["cnes_years"],
        months=cnes_months,
        billing_project_id=billing_project_id,
    )
    cnes_gdf = (_merge_by_cep(cnes_raw, ceps_gdf)
                .pipe(_to_local_utm))

    # RAIS – geocodificação via CEP
    rais_raw = fetch_rais(
        munis, years=years, billing_project_id=billing_project_id
    )
    rais_gdf = (_merge_by_cep(rais_raw, ceps_gdf)
                .pipe(_to_local_utm))

    return {"rais": rais_gdf, "cnes": cnes_gdf, "schools": schools_gdf}

# %%
camadas = load_geolocated_layers(
    munis=MUNIS,            
    years=YEARS,
    cnes_years=CNES_YEARS,          
    cnes_months=CNES_MONTHS,  
    billing_project_id=GCLOUD_ID,
)

# Resultado: dicionário com três GeoDataFrames em CRS UTM
rais_gdf    = camadas["rais"]
cnes_gdf    = camadas["cnes"]
schools_gdf = camadas["schools"]

# %%
col = "etapas_modalidades_oferecidas"  # ajuste para o nome real da sua coluna

def strip_accents(s: str) -> str:
    if pd.isna(s):
        return ""
    return "".join(c for c in unicodedata.normalize("NFD", s)
                   if unicodedata.category(c) != "Mn")

# normalização para buscas estáveis (casefold + remoção de acentos)
norm = (schools_gdf[col].astype("string")
               .fillna("")
               .map(strip_accents)
               .str.lower())

schools_gdf = schools_gdf.assign(
    infantil     = norm.str.contains(r"\binfantil\b").astype("int8"),
    fundamental  = norm.str.contains(r"\bfundamental\b").astype("int8"),
    medio        = norm.str.contains(r"\bmedio\b").astype("int8"),
    profissional = norm.str.contains(r"\bprofissional\b").astype("int8"),
    eja          = norm.str.contains(r"\badultos\b").astype("int8"),
)

# %% [markdown]
# ## Overrides

# %%
def override_geometry(
    gdf: gpd.GeoDataFrame,
    overrides: Mapping[str, Tuple[float, float]],
    *,
    id_column: str | None = None,
    crs_in: str = "EPSG:4326",
    crs_out: str = "EPSG:31983",
    drop_ids: Sequence[str] | None = None
) -> gpd.GeoDataFrame:
    """
    Substitui geometrias de um GeoDataFrame segundo um mapa de overrides.

    Parâmetros
    ----------
    gdf : GeoDataFrame original em crs_in
    overrides : mapeamento {id: (lat, lon)} (EPSG:4326)
    id_column : coluna usada como índice temporário (str ou None)
    crs_in : CRS de entrada (p.ex. 'EPSG:4326')
    crs_out: CRS de saída (p.ex. 'EPSG:31983')
    drop_ids : lista de índices a remover antes de aplicar overrides

    Retorna
    -------
    GeoDataFrame reprojetado em crs_out, com geometrias sobrescritas.
    """
    # reprojeta e copia
    working = gdf.to_crs(crs_out).copy()

    # descarta índices inválidos, se houver
    if drop_ids:
        working = working.drop(index=drop_ids, errors="ignore")

    # indexação temporária por id_column, se fornecido
    if id_column:
        working = working.set_index(working[id_column].astype(str), drop=False)

    # constrói GeoDataFrame de overrides e reprojeta
    df_ovr = pd.DataFrame.from_dict(
        {idx: {"lon": lonlat[1], "lat": lonlat[0]}
         for idx, lonlat in overrides.items()},
        orient="index"
    )
    gdf_ovr = (
        gpd.GeoDataFrame(
            df_ovr,
            geometry=gpd.points_from_xy(df_ovr.lon, df_ovr.lat),
            crs=crs_in
        )
        .to_crs(crs_out)
    )

    # aplica a substituição pontual
    working.loc[gdf_ovr.index, "geometry"] = gdf_ovr.geometry

    # restaura índice simples, se usamos id_column
    if id_column:
        working = working.reset_index(drop=True)

    return working


override_cnes_geometry = functools.partial(
    override_geometry,
    id_column="id_estabelecimento_cnes"
)

# %% [markdown]
# ## Complementações da RAIS

# %% [markdown]
# ### Grupos CNAE

# %%
def add_cnae_section(
    df: pd.DataFrame,
    cnae_col: str = "cnae_2",
    section_col: str = "cnae_group"
) -> pd.DataFrame:
    """
    A partir do campo completo de cinco dígitos `cnae_col`, preenche
    `section_col` com a letra da Seção CNAE, usando `startswith`.
    """
    # garante strings de 5 dígitos
    s = df[cnae_col].astype(str).str.zfill(5)

    # inicializa coluna com NA
    df[section_col] = np.nan

    # para cada seção, gera tupla de prefixos ("01","02",...)
    for letter, start, end in _CNAE_SECTIONS:
        prefixes = tuple(f"{i:02d}" for i in range(start, end + 1))
        mask = s.str.startswith(prefixes)
        df.loc[mask, section_col] = letter

    return df

# %%
rais_gdf = add_cnae_section(rais_gdf, cnae_col="cnae_2", section_col="grupo_cnae")

# %% [markdown]
# ### Dados de Escola Pública para a RAIS

# %%
def schools_to_rais_format(schools):
    return (
        schools
        .loc[schools.rede == 'Publica']
        .assign(
            quantidade_vinculos_ativos=lambda x: (
                x['quantidade_docente_educacao_basica']
                + x['quantidade_profissional']
                ),
            grupo_cnae='P',
            )
        .reindex(
            columns=[
                'quantidade_vinculos_ativos', 'grupo_cnae',
                'id_municipio', 'geometry', 'ano'
                ]
            )
        )

# %% [markdown]
# ### Dados de Saúde Pública para RAIS

# %%
def aggregate_cnes_jobs_by_cep(
    cnes_gdf: gpd.GeoDataFrame,
    *,
    cep_col: str = "cep",
    workers_col: str = "quantidade_trabalhadores_saude",
    output_jobs_col: str = "quantidade_vinculos_ativos",
    cnae_group: str = "Q"
) -> gpd.GeoDataFrame:
    dissolved = (
        cnes_gdf
        .loc[
            (cnes_gdf.complexidade.notnull()) # Hospital or ambulatory care
            & (cnes_gdf.indicador_vinculo_sus == '1') # SUS-linked
        ]
        .dissolve(
            by=['id_municipio', 'ano', cep_col],
            aggfunc={workers_col: "sum"}
        )
        .rename(columns={workers_col: output_jobs_col})
        .assign(grupo_cnae=cnae_group)
        .reset_index()
    )
    # garante ser GeoDataFrame
    return gpd.GeoDataFrame(dissolved, geometry="geometry", crs=cnes_gdf.crs)

# %%
rais_gdf = pd.concat([
    rais_gdf,
    aggregate_cnes_jobs_by_cep(cnes_gdf),
    schools_to_rais_format(schools_gdf),
    ])

# %% [markdown]
# # Visualizações

# %% [markdown]
# A seguir são demonstrados graficamente os totais de empregos por grupo do CNAE.

# %%
# TODO: adjust visualizations to the fact that now I have a time series

all_jobs = rais_gdf.copy()

# %%
setores_cnae = {
    "A": "Agricultura e Pesca",
    "B": "Indústrias Extrativas",
    "C": "Indústrias de Transformação",
    "D": "Eletricidade e Gás",
    "E": "Água e Gestão de Resíduos",
    "F": "Construção",
    "G": "Comércio e Reparação de Veículos",
    "H": "Transporte e Armazenagem",
    "I": "Alojamento e Alimentação",
    "J": "Informação e Comunicação",
    "K": "Finanças e Seguros",
    "L": "Atividades Imobiliárias",
    "M": "Serviços Profissionais e Técnicos",
    "N": "Serviços Administrativos",
    "O": "Administração Pública",
    "P": "Educação",
    "Q": "Saúde e Assistência Social",
    "R": "Artes e Recreação",
    "S": "Outros Serviços",
    "T": "Serviços Domésticos",
    "U": "Organizações Internacionais",
}

ibge_names = {
    '3303302': "Niterói",
    '3304904': "São Gonçalo",
    '3301900': "Itaboraí",
    #'3304557': 'Rio de Janeiro',
}

# %%
# Group data by CNAE group, year, AND city
grouped_data_by_city = (
    all_jobs
    #.dropna(subset=['cep'])
    #.replace({'id_municipio': ibge_names})
    #.assign(quantidade_vinculos_ativos=1)
    .groupby(['grupo_cnae', 'id_municipio', 'ano'], as_index=False)
    .agg({'quantidade_vinculos_ativos': 'sum'})
    .rename(columns={'quantidade_vinculos_ativos': 'Quantidade de Postos de Trabalho'})
    .astype({'ano': 'str'})
    .replace({'grupo_cnae': setores_cnae})
)

# Prepare the pivoted DataFrame
pivot_df = grouped_data_by_city.pivot(
    index='grupo_cnae', 
    columns='id_municipio', 
    values='Quantidade de Postos de Trabalho'
).fillna(0)
#).sort_values('Niterói', ascending=True).fillna(0)

pivot_df = pivot_df.iloc[pivot_df.sum(axis=1).argsort()[::-1]]

# Define city order explicitly
cities = set(str(m) for m in MUNIS) & set(pivot_df)

# Get colors from seaborn colorblind palette
colors = sns.color_palette('colorblind', n_colors=len(cities))

fig, ax = plt.subplots(figsize=(12, 10))

# Plot fully stacked bars
left = None
for city, color in zip(cities, colors):
    ax.barh(
        y=pivot_df.index,
        width=pivot_df[city],
        left=left,
        height=0.8,
        label=city,
        color=color
    )
    # Update 'left' to stack the next city's bars
    left = pivot_df[city] if left is None else left + pivot_df[city]

# Axes labels and scale
ax.set_xlabel("Quantidade de Vínculos Ativos", fontsize=14)
ax.set_ylabel("Grupo CNAE", fontsize=14)
#ax.set_xscale('log')  # Logarithmic scale for better visualization

# Customize tick parameters
ax.tick_params(axis='both', labelsize='large')

# Legend configuration
#ax.legend(
#    title='Município',
#    title_fontsize=14,
#    fontsize=12,
#    bbox_to_anchor=(1.05, 0.05),
#    loc='lower left'
#)

sns.despine()

plt.show()

# %%
df = (
    all_jobs
    .to_crs(4326)
    .assign(
        latitude=lambda x: x.geometry.y,
        longitude=lambda x: x.geometry.x
    )
)

fig = px.density_map(
    df,
    lat='latitude', lon='longitude', z='quantidade_vinculos_ativos',
    radius=30, #center=dict(lat=-23.0, lon=-43.2),
    zoom=11, map_style="carto-voyager",
    height=700
)
fig.show(config={"scrollZoom": True})

# %%
df = rais_gdf
df.loc[df.grupo_cnae == 'C'].to_csv('industrias_transformacao.csv', index=False)

# %%
df.value_counts?

# %% [markdown]
# # Backup

# %%
OUT_PARQUET = (
    OUT_DIR
    / f"rais/rais.parquet"
    )
rais_gdf.to_parquet(OUT_PARQUET, index=False)


OUT_PARQUET = (
    OUT_DIR
    / f"schools/schools.parquet"
    )
schools_gdf.to_parquet(OUT_PARQUET, index=False)


OUT_PARQUET = (
    OUT_DIR
    / f"cnes/cnes.parquet"
    )
cnes_gdf.to_parquet(OUT_PARQUET, index=False)

# %% [markdown]
# # Exercício
#
# **Objetivo:** Compreender os fundamentos da análise de padrões de pontos (*Point Pattern Analysis*) e explorar técnicas para visualizar e interpretar eventos espaciais representados como pontos georreferenciados.

# %% [markdown]
# Abaixo, está um mapa com uma amostra ds emprgos da RAIS, representados por pontos que são a localização geogr;afica dos respectivos CEPs.

# %% [markdown]
# Pontos no espaço podem representar fenômenos distintos dependendo de como os interpretamos. No caso da RAIS, ao geolocalizarmos estabelecimentos com base em seus CEPs, podemos tratá-los como **eventos que poderiam ocorrer em qualquer lugar da cidade, mas que se concentram em alguns pontos específicos**. Nesse contexto, nos interessa entender *por que* esses eventos (estabelecimentos) ocorrem em certas áreas e *como* estão distribuídos espacialmente.
#
# Esse tipo de análise — conhecida como **padrão de pontos** — busca descrever e modelar a distribuição dos eventos no espaço. A distribuição pode ser:
# - **Aleatória**, sem nenhuma estrutura evidente;
# - **Agrupada**, sugerindo concentração em certas regiões;
# - Ou **dispersa**, indicando distanciamento entre eventos.
#
# A análise nos permite transformar listas de coordenadas em **fenômenos espaciais interpretáveis**, ajudando a responder perguntas como:
# - Onde estão os centros de atividade econômica?
# - Existem “vazios” no espaço urbano sem estabelecimentos?
# - Há evidência de *clusters* (aglomerados) por setor ou tipo de empresa?
#
# Trabalhe com os dados geolocalizados da RAIS, tratando cada ponto como uma observação de um processo espacial subjacente. A proposta é aplicar conceitos e ferramentas de análise de padrões pontuais para caracterizar a estrutura espacial dos dados — usando bibliotecas como `geopandas`, `pointpats` e `PySAL`.
#
# Acompanhe o capítulo Point Pattern Analysis do livro [Geographic Data Science with Python](https://geographicdata.science/book/notebooks/08_point_pattern_analysis.html) e reproduza o exercício prático lá contido com os municípios acima. Documente o passo a passo e discuta e analise seus achados.
#
# → Note que exportamos dados de três anos (2021, 2022 e 2023). Extraia 2023 e faça as análises com esse subconjunto.
# → Você pode trabalhar com os dados agregados, mas pode ser interessante ver como a análise muda para as diferentes categorias do CONCLA.

# %%
OUT_PARQUET    = (
    Path("../outputs/sociodemografia")
    / f"sociodemografia_hex_r9_{'-'.join(str(m) for m in MUNIS)}.parquet"
)
OUT_PARQUET

# %%
hexes = (
    gpd
    .read_parquet(OUT_PARQUET)
    .reindex(
        columns=[
            'year',
            'geometry'
            ]
        )
    .pipe(
        lambda x: x.loc[x.year==2022]
        )
    .reset_index()
)
