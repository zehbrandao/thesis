# %%
import os
from pathlib import Path

import geobr
import basedosdados as bd
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt

# %%
bh = geobr.read_census_tract(code_tract=3106200, year=2010, simplified=False)

(bh.to_crs(epsg=31983).area / 10**6).describe()
# Out:
# count    3936.000000
# mean        0.084155
# std         0.295825
# min         0.000409
# 25%         0.025668
# 50%         0.049619
# 75%         0.079132
# max        12.881002
# dtype: float64
